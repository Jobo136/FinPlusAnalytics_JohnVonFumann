# %%
import sys
from pyspark.sql import SparkSession
# Añadir la carpeta 'src' al PATH para poder importar los módulos
# La ruta es relativa al directorio 'work' del contenedor
sys.path.append('/home/jovyan/work/src') 

# Importar la función que necesitas de tu módulo
import sql_generator as sql_gen

# %%
# 1. INICIALIZAR SPARK
spark = (SparkSession.builder
    .appName("MainPipeline")
    .getOrCreate()
)

# 2. CARGAR DATOS (Simulación de Extracción)
df_clients = spark.read.csv("/home/jovyan/work/data/CLIENTS.csv", header=True, inferSchema=True)
df_behaviour = spark.read.csv("/home/jovyan/work/data/BEHAVIOURAL.csv", header=True, inferSchema=True)

# %%
# 3. LLAMAR A FUNCIÓN DE MÓDULO (Limpieza/Transformación)
# Llamamos a la función que crea las vistas SQL:
sql_gen.create_temp_views(spark, df_clients, df_behaviour)
# Out:
# Vistas SQL 'clients' y 'behaviour' creadas.

# %%
# 4. EJECUTAR CONSULTA MODULAR
sql_query = sql_gen.get_base_segmentation_query()
df_final = spark.sql(sql_query)

print("\nResultados de la consulta modular:")
df_final.show()

spark.stop()
# Out:
# Resultados de la consulta modular:
# +------------+-----------------+--------------------+-------------------+
# |   CLIENT_ID|     AGE_IN_YEARS|CREDICT_CARD_BALANCE|CREDIT_CARD_PAYMENT|
# +------------+-----------------+--------------------+-------------------+
# |ES182129853D|39.31780821917808|             9530.72|            1340.64|
# |ES182129853D|39.31780821917808|             7289.12|             551.04|
# |ES182129853D|39.31780821917808|              881.08|                0.0|
# |ES182129853D|39.31780821917808|             4217.71|             279.33|
# |ES182129853D|39.31780821917808|            10747.59|             586.63|
# |ES182129853D|39.31780821917808|              8516.3|              562.5|
# |ES182129853D|39.31780821917808|              8946.7|             568.92|
# |ES182129853D|39.31780821917808|            10645.18|              567.0|
# |ES182129853D|39.31780821917808|             2432.95|             167.78|
# |ES182129853D|39.31780821917808|            10853.28|              567.0|
# +------------+-----------------+--------------------+-------------------+
