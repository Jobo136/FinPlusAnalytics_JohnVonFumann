# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path

# %%
# Directorio dentro del contenedor donde montas tus datos
DATA_DIR = Path("/home/jovyan/work/data/")

# Nombre del CSV de entrada (dentro de /data)
csv_clientes = "CLIENTS.csv"
csv_behavioural = "BEHAVIOURAL.csv"
parquet_clientes = "CLIENTS.parquet"  # opcional: mismo nombre pero .parquet
parquet_behavioural = "BEHAVIOURAL.parquet"  # opcional: mismo nombre pero .parquet

# Tamaño del chunk (ajusta según tu RAM)
CHUNKSIZE = 100_000
